# %%
import pandas as pd

# %%
file_path = "Elementary and secondary private schools, by type of expenditure.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#     REF_DATE     GEO  DGUID                   Type of expenditure      UOM  \
# 0  1947/1948  Canada    NaN                    Total expenditures  Dollars
# 1  1947/1948  Canada    NaN          Total operating expenditures  Dollars
# 2  1947/1948  Canada    NaN   Subtotal instructional expenditures  Dollars
# 3  1947/1948  Canada    NaN                     Teachers salaries  Dollars
# 4  1947/1948  Canada    NaN  Non-instructional salaries and wages  Dollars
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE    VALUE STATUS  \
# 0      81     thousands          3  v1568007         1.1  13951.0    NaN
# 1      81     thousands          3  v1568013         1.7  13951.0    NaN
# 2      81     thousands          3  v1568010         1.4   3742.0    NaN
# 3      81     thousands          3  v1568008         1.2   3742.0    NaN
# 4      81     thousands          3  v1568011         1.5   1965.0    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         0
# 1     NaN         NaN         0
# 2     NaN         NaN         0
# 3     NaN         NaN         0
# 4     NaN         NaN         0

# %%
# Keep only the left year
df['REF_DATE'] = df['REF_DATE'].str[:4]

# %%
df.head()
# Out:
#   REF_DATE     GEO  DGUID                   Type of expenditure      UOM  \
# 0     1947  Canada    NaN                    Total expenditures  Dollars
# 1     1947  Canada    NaN          Total operating expenditures  Dollars
# 2     1947  Canada    NaN   Subtotal instructional expenditures  Dollars
# 3     1947  Canada    NaN                     Teachers salaries  Dollars
# 4     1947  Canada    NaN  Non-instructional salaries and wages  Dollars
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR  COORDINATE    VALUE STATUS  \
# 0      81     thousands          3  v1568007         1.1  13951.0    NaN
# 1      81     thousands          3  v1568013         1.7  13951.0    NaN
# 2      81     thousands          3  v1568010         1.4   3742.0    NaN
# 3      81     thousands          3  v1568008         1.2   3742.0    NaN
# 4      81     thousands          3  v1568011         1.5   1965.0    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         0
# 1     NaN         NaN         0
# 2     NaN         NaN         0
# 3     NaN         NaN         0
# 4     NaN         NaN         0

# %%
# Keep only the required columns
df = df[['REF_DATE', 'GEO', 'Type of expenditure', 'VALUE']]

# %%
df.head()
# Out:
#   REF_DATE     GEO                   Type of expenditure    VALUE
# 0     1947  Canada                    Total expenditures  13951.0
# 1     1947  Canada          Total operating expenditures  13951.0
# 2     1947  Canada   Subtotal instructional expenditures   3742.0
# 3     1947  Canada                     Teachers salaries   3742.0
# 4     1947  Canada  Non-instructional salaries and wages   1965.0

# %%
# Filter the dataframe
filtered_df = df[df["Type of expenditure"].isin([
    "Total expenditures",
    "Total operating expenditures",
    "Teachers salaries",
    "Capita outlay and debt charges"
])]

# %%
filtered_df
# Out:
#      REF_DATE                    GEO             Type of expenditure    VALUE
# 0        1947                 Canada              Total expenditures  13951.0
# 1        1947                 Canada    Total operating expenditures  13951.0
# 3        1947                 Canada               Teachers salaries   3742.0
# 6        1947                 Canada  Capita outlay and debt charges      0.0
# 7        1947      Atlantic Province              Total expenditures    744.0
# ...       ...                    ...                             ...      ...
# 5339     2002                  Yukon  Capita outlay and debt charges      0.0
# 5340     2002  Northwest Territories              Total expenditures    303.0
# 5341     2002  Northwest Territories    Total operating expenditures    303.0
# 5343     2002  Northwest Territories               Teachers salaries     49.0
# 5347     2002  Northwest Territories  Capita outlay and debt charges      0.0
#
# [2752 rows x 4 columns]

# %%
# Define the list of GEO values to keep
geo_list = [
    "Canada", "Quebec", "Ontario", "British Columbia", "Alberta", 
    "Manitoba", "New Brunswick", "Newfoundland and Labrador", 
    "Nova Scotia", "Saskatchewan", "Prince Edward Island"
]

# Filter the DataFrame to keep only these GEO values
filtered_df = filtered_df[filtered_df['GEO'].isin(geo_list)].reset_index(drop=True)

# %%
filtered_df
# Out:
#      REF_DATE                        GEO             Type of expenditure  \
# 0        1947                     Canada              Total expenditures
# 1        1947                     Canada    Total operating expenditures
# 2        1947                     Canada               Teachers salaries
# 3        1947                     Canada  Capita outlay and debt charges
# 4        1947  Newfoundland and Labrador              Total expenditures
# ...       ...                        ...                             ...
# 2459     2002                    Alberta  Capita outlay and debt charges
# 2460     2002           British Columbia              Total expenditures
# 2461     2002           British Columbia    Total operating expenditures
# 2462     2002           British Columbia               Teachers salaries
# 2463     2002           British Columbia  Capita outlay and debt charges
#
#          VALUE
# 0      13951.0
# 1      13951.0
# 2       3742.0
# 3          0.0
# 4          NaN
# ...        ...
# 2459   17373.0
# 2460  476518.0
# 2461  427825.0
# 2462  245399.0
# 2463   48693.0
#
# [2464 rows x 4 columns]

# %%
# Adding index column
filtered_df.insert(0, 'Index', range(1, len(filtered_df) + 1))

# %%
filtered_df
# Out:
#       Index REF_DATE                        GEO  \
# 0         1     1947                     Canada
# 1         2     1947                     Canada
# 2         3     1947                     Canada
# 3         4     1947                     Canada
# 4         5     1947  Newfoundland and Labrador
# ...     ...      ...                        ...
# 2459   2460     2002                    Alberta
# 2460   2461     2002           British Columbia
# 2461   2462     2002           British Columbia
# 2462   2463     2002           British Columbia
# 2463   2464     2002           British Columbia
#
#                  Type of expenditure     VALUE
# 0                 Total expenditures   13951.0
# 1       Total operating expenditures   13951.0
# 2                  Teachers salaries    3742.0
# 3     Capita outlay and debt charges       0.0
# 4                 Total expenditures       NaN
# ...                              ...       ...
# 2459  Capita outlay and debt charges   17373.0
# 2460              Total expenditures  476518.0
# 2461    Total operating expenditures  427825.0
# 2462               Teachers salaries  245399.0
# 2463  Capita outlay and debt charges   48693.0
#
# [2464 rows x 5 columns]

# %%
#pivoting the Graduation rate column
df_pivot = filtered_df.pivot(index=['REF_DATE', 'GEO', 'Index'], columns="Type of expenditure", values='VALUE').reset_index()

# %%
df_pivot
# Out:
# Type of expenditure REF_DATE               GEO  Index  \
# 0                       1947           Alberta     37
# 1                       1947           Alberta     38
# 2                       1947           Alberta     39
# 3                       1947           Alberta     40
# 4                       1947  British Columbia     41
# ...                      ...               ...    ...
# 2459                    2002            Quebec   2444
# 2460                    2002      Saskatchewan   2453
# 2461                    2002      Saskatchewan   2454
# 2462                    2002      Saskatchewan   2455
# 2463                    2002      Saskatchewan   2456
#
# Type of expenditure  Capita outlay and debt charges  Teachers salaries  \
# 0                                               NaN                NaN
# 1                                               NaN                NaN
# 2                                               NaN              186.0
# 3                                               0.0                NaN
# 4                                               NaN                NaN
# ...                                             ...                ...
# 2459                                        41789.0                NaN
# 2460                                            NaN                NaN
# 2461                                            NaN                NaN
# 2462                                            NaN            11148.0
# 2463                                          814.0                NaN
#
# Type of expenditure  Total expenditures  Total operating expenditures
# 0                                 528.0                           NaN
# 1                                   NaN                         528.0
# 2                                   NaN                           NaN
# 3                                   NaN                           NaN
# 4                                1265.0                           NaN
# ...                                 ...                           ...
# 2459                                NaN                           NaN
# 2460                            36605.0                           NaN
# 2461                                NaN                       35791.0
# 2462                                NaN                           NaN
# 2463                                NaN                           NaN
#
# [2464 rows x 7 columns]

# %%
df_pivot.reset_index(drop=True, inplace=True)
df_pivot.columns
# Out:
# Index(['REF_DATE', 'GEO', 'Index', 'Capita outlay and debt charges',
#        'Teachers salaries', 'Total expenditures',
#        'Total operating expenditures'],
#       dtype='object', name='Type of expenditure')

# %%
## Group the data by REF_DATE and GEO without setting them as index
grouped_df = df_pivot.groupby(['REF_DATE', 'GEO'], as_index=False).agg({
    'Index': 'first',  
    'Capita outlay and debt charges': 'first',    
    'Teachers salaries': 'first',
    'Total expenditures': 'first',
    'Total operating expenditures': 'first'
})

# %%
grouped_df
# Out:
# Type of expenditure REF_DATE                   GEO  Index  \
# 0                       1947               Alberta     37
# 1                       1947      British Columbia     41
# 2                       1947                Canada      1
# 3                       1947              Manitoba     29
# 4                       1947         New Brunswick     17
# ..                       ...                   ...    ...
# 611                     2002           Nova Scotia   2433
# 612                     2002               Ontario   2445
# 613                     2002  Prince Edward Island   2429
# 614                     2002                Quebec   2441
# 615                     2002          Saskatchewan   2453
#
# Type of expenditure  Capita outlay and debt charges  Teachers salaries  \
# 0                                               0.0              186.0
# 1                                               0.0              224.0
# 2                                               0.0             3742.0
# 3                                               0.0              106.0
# 4                                               NaN                NaN
# ..                                              ...                ...
# 611                                             NaN                NaN
# 612                                         99215.0           452073.0
# 613                                             NaN                NaN
# 614                                         41789.0           390213.0
# 615                                           814.0            11148.0
#
# Type of expenditure  Total expenditures  Total operating expenditures
# 0                                 528.0                         528.0
# 1                                1265.0                        1265.0
# 2                               13951.0                       13951.0
# 3                                 556.0                         556.0
# 4                                   NaN                           NaN
# ..                                  ...                           ...
# 611                                 NaN                           NaN
# 612                           1023249.0                      924033.0
# 613                                 NaN                           NaN
# 614                            821906.0                      780117.0
# 615                             36605.0                       35791.0
#
# [616 rows x 7 columns]

# %%
#Dropping the Index column
grouped_df.drop(columns=['Index'], inplace=True)

# %%
# Remove column index name if it exists
grouped_df.columns.name = None

# %%
grouped_df
# Out:
#     REF_DATE                   GEO  Capita outlay and debt charges  \
# 0       1947               Alberta                             0.0
# 1       1947      British Columbia                             0.0
# 2       1947                Canada                             0.0
# 3       1947              Manitoba                             0.0
# 4       1947         New Brunswick                             NaN
# ..       ...                   ...                             ...
# 611     2002           Nova Scotia                             NaN
# 612     2002               Ontario                         99215.0
# 613     2002  Prince Edward Island                             NaN
# 614     2002                Quebec                         41789.0
# 615     2002          Saskatchewan                           814.0
#
#      Teachers salaries  Total expenditures  Total operating expenditures
# 0                186.0               528.0                         528.0
# 1                224.0              1265.0                        1265.0
# 2               3742.0             13951.0                       13951.0
# 3                106.0               556.0                         556.0
# 4                  NaN                 NaN                           NaN
# ..                 ...                 ...                           ...
# 611                NaN                 NaN                           NaN
# 612           452073.0           1023249.0                      924033.0
# 613                NaN                 NaN                           NaN
# 614           390213.0            821906.0                      780117.0
# 615            11148.0             36605.0                       35791.0
#
# [616 rows x 6 columns]

# %%
grouped_df = grouped_df.interpolate(method='linear')
# Out:
# C:\Users\mihir\AppData\Local\Temp\ipykernel_11728\4286533720.py:1: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   grouped_df = grouped_df.interpolate(method='linear')

# %%
grouped_df = grouped_df.drop(columns=["Capita outlay and debt charges"])

# %%
grouped_df
# Out:
#     REF_DATE                   GEO  Teachers salaries  Total expenditures  \
# 0       1947               Alberta             186.00              528.00
# 1       1947      British Columbia             224.00             1265.00
# 2       1947                Canada            3742.00            13951.00
# 3       1947              Manitoba             106.00              556.00
# 4       1947         New Brunswick             387.25             1544.25
# ..       ...                   ...                ...                 ...
# 611     2002           Nova Scotia          352476.25           792489.75
# 612     2002               Ontario          452073.00          1023249.00
# 613     2002  Prince Edward Island          421143.00           922577.50
# 614     2002                Quebec          390213.00           821906.00
# 615     2002          Saskatchewan           11148.00            36605.00
#
#      Total operating expenditures
# 0                          528.00
# 1                         1265.00
# 2                        13951.00
# 3                          556.00
# 4                         1544.25
# ..                            ...
# 611                     716783.25
# 612                     924033.00
# 613                     852075.00
# 614                     780117.00
# 615                      35791.00
#
# [616 rows x 5 columns]

# %%
grouped_df.to_csv("Prepared_Expenditures.csv", index=False)
