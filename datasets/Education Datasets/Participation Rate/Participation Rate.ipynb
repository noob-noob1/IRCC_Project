# %%
import pandas as pd
import os

# %%
# Define the folder path where the CSV files are located
folder_path = "."

# %%
# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith(".csv")]

# %%
# Initialize an empty list to store DataFrames
dfs = []

# Read each CSV file and append it to the list
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df['Source_File'] = file  # Optional: Track the file each row came from
    dfs.append(df)

# Concatenate all DataFrames
merged_df = pd.concat(dfs, ignore_index=True)

# %%
df
# Out:
#        REF_DATE      GEO           DGUID       Age group  \
# 0     1995/1996   Canada  2021A000011124  18 to 24 years
# 1     1995/1996   Canada  2021A000011124  18 to 24 years
# 2     1995/1996   Canada  2021A000011124  18 to 24 years
# 3     1995/1996   Canada  2021A000011124  18 to 24 years
# 4     1995/1996   Canada  2021A000011124  25 to 29 years
# ...         ...      ...             ...             ...
# 3442  2023/2024  Nunavut     2021A000262  25 to 29 years
# 3443  2023/2024  Nunavut     2021A000262  30 to 34 years
# 3444  2023/2024  Nunavut     2021A000262  30 to 34 years
# 3445  2023/2024  Nunavut     2021A000262  30 to 34 years
# 3446  2023/2024  Nunavut     2021A000262  30 to 34 years
#
#      Participation rate by type of institution attended      UOM  UOM_ID  \
# 0                              Total participation rate  Percent     239
# 1                         Elementary and/or High School  Percent     239
# 2                                               College  Percent     239
# 3                                            University  Percent     239
# 4                              Total participation rate  Percent     239
# ...                                                 ...      ...     ...
# 3442                                         University  Percent     239
# 3443                           Total participation rate  Percent     239
# 3444                      Elementary and/or High School  Percent     239
# 3445                                            College  Percent     239
# 3446                                         University  Percent     239
#
#      SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS  SYMBOL  \
# 0            units          0  v99915216      1.1.1   42.0      A     NaN
# 1            units          0  v99915217      1.1.2    9.0      A     NaN
# 2            units          0  v99915218      1.1.3   15.0      A     NaN
# 3            units          0  v99915219      1.1.4   19.0      A     NaN
# 4            units          0  v99915220      1.2.1   10.0      A     NaN
# ...            ...        ...        ...        ...    ...    ...     ...
# 3442         units          0  v99915379     14.2.4    NaN      x     NaN
# 3443         units          0  v99915380     14.3.1    NaN      x     NaN
# 3444         units          0  v99915381     14.3.2    NaN      x     NaN
# 3445         units          0  v99915382     14.3.3    NaN      x     NaN
# 3446         units          0  v99915383     14.3.4    NaN      x     NaN
#
#       TERMINATED  DECIMALS                                        Source_File
# 0            NaN         0  Participation rate in education, population ag...
# 1            NaN         0  Participation rate in education, population ag...
# 2            NaN         0  Participation rate in education, population ag...
# 3            NaN         0  Participation rate in education, population ag...
# 4            NaN         0  Participation rate in education, population ag...
# ...          ...       ...                                                ...
# 3442         NaN         0  Participation rate in education, population ag...
# 3443         NaN         0  Participation rate in education, population ag...
# 3444         NaN         0  Participation rate in education, population ag...
# 3445         NaN         0  Participation rate in education, population ag...
# 3446         NaN         0  Participation rate in education, population ag...
#
# [3447 rows x 17 columns]

# %%
# Keep only the required columns
df = df[['REF_DATE', 'GEO', 'Participation rate by type of institution attended', 'VALUE']]

# %%
df
# Out:
#        REF_DATE      GEO Participation rate by type of institution attended  \
# 0     1995/1996   Canada                           Total participation rate
# 1     1995/1996   Canada                      Elementary and/or High School
# 2     1995/1996   Canada                                            College
# 3     1995/1996   Canada                                         University
# 4     1995/1996   Canada                           Total participation rate
# ...         ...      ...                                                ...
# 3442  2023/2024  Nunavut                                         University
# 3443  2023/2024  Nunavut                           Total participation rate
# 3444  2023/2024  Nunavut                      Elementary and/or High School
# 3445  2023/2024  Nunavut                                            College
# 3446  2023/2024  Nunavut                                         University
#
#       VALUE
# 0      42.0
# 1       9.0
# 2      15.0
# 3      19.0
# 4      10.0
# ...     ...
# 3442    NaN
# 3443    NaN
# 3444    NaN
# 3445    NaN
# 3446    NaN
#
# [3447 rows x 4 columns]

# %%
# Define the list of GEO values to keep
geo_list = [
    "Canada", "Quebec", "Ontario", "British Columbia", "Alberta", 
    "Manitoba", "New Brunswick", "Newfoundland and Labrador", 
    "Nova Scotia", "Saskatchewan", "Prince Edward Island"
]

# Filter the DataFrame to keep only these GEO values
df = df[df['GEO'].isin(geo_list)].reset_index(drop=True)

# %%
df
# Out:
#        REF_DATE               GEO  \
# 0     1995/1996            Canada
# 1     1995/1996            Canada
# 2     1995/1996            Canada
# 3     1995/1996            Canada
# 4     1995/1996            Canada
# ...         ...               ...
# 2727  2023/2024  British Columbia
# 2728  2023/2024  British Columbia
# 2729  2023/2024  British Columbia
# 2730  2023/2024  British Columbia
# 2731  2023/2024  British Columbia
#
#      Participation rate by type of institution attended  VALUE
# 0                              Total participation rate   42.0
# 1                         Elementary and/or High School    9.0
# 2                                               College   15.0
# 3                                            University   19.0
# 4                              Total participation rate   10.0
# ...                                                 ...    ...
# 2727                                         University    7.0
# 2728                           Total participation rate    6.0
# 2729                      Elementary and/or High School    NaN
# 2730                                            College    2.0
# 2731                                         University    3.0
#
# [2732 rows x 4 columns]

# %%
# Keep only the left year
df['REF_DATE'] = df['REF_DATE'].str[:4]

# %%
df
# Out:
#      REF_DATE               GEO  \
# 0        1995            Canada
# 1        1995            Canada
# 2        1995            Canada
# 3        1995            Canada
# 4        1995            Canada
# ...       ...               ...
# 2727     2023  British Columbia
# 2728     2023  British Columbia
# 2729     2023  British Columbia
# 2730     2023  British Columbia
# 2731     2023  British Columbia
#
#      Participation rate by type of institution attended  VALUE
# 0                              Total participation rate   42.0
# 1                         Elementary and/or High School    9.0
# 2                                               College   15.0
# 3                                            University   19.0
# 4                              Total participation rate   10.0
# ...                                                 ...    ...
# 2727                                         University    7.0
# 2728                           Total participation rate    6.0
# 2729                      Elementary and/or High School    NaN
# 2730                                            College    2.0
# 2731                                         University    3.0
#
# [2732 rows x 4 columns]

# %%
df = df[df["Participation rate by type of institution attended"] != "Total participation rate"]

# %%
df
# Out:
#      REF_DATE               GEO  \
# 1        1995            Canada
# 2        1995            Canada
# 3        1995            Canada
# 5        1995            Canada
# 6        1995            Canada
# ...       ...               ...
# 2726     2023  British Columbia
# 2727     2023  British Columbia
# 2729     2023  British Columbia
# 2730     2023  British Columbia
# 2731     2023  British Columbia
#
#      Participation rate by type of institution attended  VALUE
# 1                         Elementary and/or High School    9.0
# 2                                               College   15.0
# 3                                            University   19.0
# 5                         Elementary and/or High School    1.0
# 6                                               College    4.0
# ...                                                 ...    ...
# 2726                                            College    4.0
# 2727                                         University    7.0
# 2729                      Elementary and/or High School    NaN
# 2730                                            College    2.0
# 2731                                         University    3.0
#
# [2039 rows x 4 columns]

# %%
# Adding index column
df.insert(0, 'Index', range(1, len(df) + 1))

# %%
#pivoting the Graduation rate column
df_pivot = df.pivot(index=['REF_DATE', 'GEO', 'Index'], columns="Participation rate by type of institution attended", values='VALUE').reset_index()

# %%
df_pivot
# Out:
# Participation rate by type of institution attended REF_DATE           GEO  \
# 0                                                      1995       Alberta
# 1                                                      1995       Alberta
# 2                                                      1995       Alberta
# 3                                                      1995       Alberta
# 4                                                      1995       Alberta
# ...                                                     ...           ...
# 2034                                                   2023  Saskatchewan
# 2035                                                   2023  Saskatchewan
# 2036                                                   2023  Saskatchewan
# 2037                                                   2023  Saskatchewan
# 2038                                                   2023  Saskatchewan
#
# Participation rate by type of institution attended  Index  College  \
# 0                                                      82      NaN
# 1                                                      83     11.0
# 2                                                      84      NaN
# 3                                                      85      NaN
# 4                                                      86      5.0
# ...                                                   ...      ...
# 2034                                                 2017      3.0
# 2035                                                 2018      NaN
# 2036                                                 2019      NaN
# 2037                                                 2020      1.0
# 2038                                                 2021      NaN
#
# Participation rate by type of institution attended  Elementary and/or High School  \
# 0                                                                             7.0
# 1                                                                             NaN
# 2                                                                             NaN
# 3                                                                             NaN
# 4                                                                             NaN
# ...                                                                           ...
# 2034                                                                          NaN
# 2035                                                                          NaN
# 2036                                                                          NaN
# 2037                                                                          NaN
# 2038                                                                          NaN
#
# Participation rate by type of institution attended  University
# 0                                                          NaN
# 1                                                          NaN
# 2                                                         15.0
# 3                                                          NaN
# 4                                                          NaN
# ...                                                        ...
# 2034                                                       NaN
# 2035                                                       8.0
# 2036                                                       NaN
# 2037                                                       NaN
# 2038                                                       4.0
#
# [2039 rows x 6 columns]

# %%
df_pivot.reset_index(drop=True, inplace=True)
df_pivot.columns
# Out:
# Index(['REF_DATE', 'GEO', 'Index', 'College', 'Elementary and/or High School',
#        'University'],
#       dtype='object', name='Participation rate by type of institution attended')

# %%
## Group the data by REF_DATE and GEO without setting them as index
grouped_df = df_pivot.groupby(['REF_DATE', 'GEO'], as_index=False).agg({
    'Index': 'first',  
    'College': 'first',    
    'Elementary and/or High School': 'first',
    'University':'first'
})

# %%
grouped_df
# Out:
# Participation rate by type of institution attended REF_DATE  \
# 0                                                      1995
# 1                                                      1995
# 2                                                      1995
# 3                                                      1995
# 4                                                      1995
# ..                                                      ...
# 226                                                    2023
# 227                                                    2023
# 228                                                    2023
# 229                                                    2023
# 230                                                    2023
#
# Participation rate by type of institution attended                   GEO  \
# 0                                                                Alberta
# 1                                                       British Columbia
# 2                                                                 Canada
# 3                                                               Manitoba
# 4                                                          New Brunswick
# ..                                                                   ...
# 226                                                          Nova Scotia
# 227                                                              Ontario
# 228                                                 Prince Edward Island
# 229                                                               Quebec
# 230                                                         Saskatchewan
#
# Participation rate by type of institution attended  Index  College  \
# 0                                                      82     11.0
# 1                                                      91     15.0
# 2                                                       1     15.0
# 3                                                      64      5.0
# 4                                                      37      8.0
# ..                                                    ...      ...
# 226                                                  1970      9.0
# 227                                                  1995     13.0
# 228                                                  1962     10.0
# 229                                                  1986     23.0
# 230                                                  2013      6.0
#
# Participation rate by type of institution attended  Elementary and/or High School  \
# 0                                                                             7.0
# 1                                                                             5.0
# 2                                                                             9.0
# 3                                                                             7.0
# 4                                                                             6.0
# ..                                                                            ...
# 226                                                                           4.0
# 227                                                                           5.0
# 228                                                                           4.0
# 229                                                                           4.0
# 230                                                                           7.0
#
# Participation rate by type of institution attended  University
# 0                                                         15.0
# 1                                                         16.0
# 2                                                         19.0
# 3                                                         20.0
# 4                                                         19.0
# ..                                                         ...
# 226                                                       28.0
# 227                                                       36.0
# 228                                                       30.0
# 229                                                       24.0
# 230                                                       30.0
#
# [231 rows x 6 columns]

# %%
#Dropping the Index column
grouped_df.drop(columns=['Index'], inplace=True)

# %%
# Remove column index name if it exists
grouped_df.columns.name = None

# %%
grouped_df
# Out:
#     REF_DATE                   GEO  College  Elementary and/or High School  \
# 0       1995               Alberta     11.0                            7.0
# 1       1995      British Columbia     15.0                            5.0
# 2       1995                Canada     15.0                            9.0
# 3       1995              Manitoba      5.0                            7.0
# 4       1995         New Brunswick      8.0                            6.0
# ..       ...                   ...      ...                            ...
# 226     2023           Nova Scotia      9.0                            4.0
# 227     2023               Ontario     13.0                            5.0
# 228     2023  Prince Edward Island     10.0                            4.0
# 229     2023                Quebec     23.0                            4.0
# 230     2023          Saskatchewan      6.0                            7.0
#
#      University
# 0          15.0
# 1          16.0
# 2          19.0
# 3          20.0
# 4          19.0
# ..          ...
# 226        28.0
# 227        36.0
# 228        30.0
# 229        24.0
# 230        30.0
#
# [231 rows x 5 columns]

# %%
grouped_df.to_csv("Prepared_GraduationRate.csv", index=False)
