# %%
import pandas as pd

# %%
file_path = "Education price index (EPI), elementary and secondary.csv"
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    REF_DATE     GEO  DGUID              Index categories           Base year  \
# 0      1971  Canada    NaN   Education price index (EPI)  Base year 1986=100
# 1      1971  Canada    NaN   Education price index (EPI)  Base year 1992=100
# 2      1971  Canada    NaN  Salaries and wages sub-index  Base year 1986=100
# 3      1971  Canada    NaN  Salaries and wages sub-index  Base year 1992=100
# 4      1971  Canada    NaN  Teachers' salaries sub-index  Base year 1986=100
#
#      UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE  VALUE  STATUS  \
# 0  Index     160        units           0  v1026884      1.1.1  29.82     NaN
# 1  Index     160        units           0  v1026885      1.1.2  22.82     NaN
# 2  Index     160        units           0  v1026886      1.2.1  30.51     NaN
# 3  Index     160        units           0  v1026887      1.2.2  23.36     NaN
# 4  Index     160        units           0  v1026888      1.3.1  30.91     NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         2
# 1     NaN         NaN         2
# 2     NaN         NaN         2
# 3     NaN         NaN         2
# 4     NaN         NaN         2

# %%
# Define the list of GEO values to keep
geo_list = [
    "Canada", "Quebec", "Ontario", "British Columbia", "Alberta", 
    "Manitoba", "New Brunswick", "Newfoundland and Labrador", 
    "Nova Scotia", "Saskatchewan", "Prince Edward Island"
]

# Filter the DataFrame to keep only these GEO values
df = df[df['GEO'].isin(geo_list)].reset_index(drop=True)

# %%
df
# Out:
#       REF_DATE               GEO  DGUID  \
# 0         1971            Canada    NaN
# 1         1971            Canada    NaN
# 2         1971            Canada    NaN
# 3         1971            Canada    NaN
# 4         1971            Canada    NaN
# ...        ...               ...    ...
# 5803      2003  British Columbia    NaN
# 5804      2003  British Columbia    NaN
# 5805      2003  British Columbia    NaN
# 5806      2003  British Columbia    NaN
# 5807      2003  British Columbia    NaN
#
#                                        Index categories           Base year  \
# 0                           Education price index (EPI)  Base year 1986=100
# 1                           Education price index (EPI)  Base year 1992=100
# 2                          Salaries and wages sub-index  Base year 1986=100
# 3                          Salaries and wages sub-index  Base year 1992=100
# 4                          Teachers' salaries sub-index  Base year 1986=100
# ...                                                 ...                 ...
# 5803                   Instructional supplies sub-index  Base year 1992=100
# 5804  School facilities, supplies and services sub-i...  Base year 1986=100
# 5805  School facilities, supplies and services sub-i...  Base year 1992=100
# 5806            Fees and contractual services sub-index  Base year 1986=100
# 5807            Fees and contractual services sub-index  Base year 1992=100
#
#         UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID    VECTOR COORDINATE   VALUE  \
# 0     Index     160        units           0  v1026884      1.1.1   29.82
# 1     Index     160        units           0  v1026885      1.1.2   22.82
# 2     Index     160        units           0  v1026886      1.2.1   30.51
# 3     Index     160        units           0  v1026887      1.2.2   23.36
# 4     Index     160        units           0  v1026888      1.3.1   30.91
# ...     ...     ...           ...        ...       ...        ...     ...
# 5803  Index     160        units           0  v1027055     11.6.2  168.51
# 5804  Index     160        units           0  v1027056     11.7.1  146.89
# 5805  Index     160        units           0  v1027057     11.7.2  133.22
# 5806  Index     160        units           0  v1027058     11.8.1  196.16
# 5807  Index     160        units           0  v1027059     11.8.2  144.07
#
#       STATUS  SYMBOL  TERMINATED  DECIMALS
# 0        NaN     NaN         NaN         2
# 1        NaN     NaN         NaN         2
# 2        NaN     NaN         NaN         2
# 3        NaN     NaN         NaN         2
# 4        NaN     NaN         NaN         2
# ...      ...     ...         ...       ...
# 5803     NaN     NaN         NaN         2
# 5804     NaN     NaN         NaN         2
# 5805     NaN     NaN         NaN         2
# 5806     NaN     NaN         NaN         2
# 5807     NaN     NaN         NaN         2
#
# [5808 rows x 16 columns]

# %%
# Keep only the required columns
df = df[['REF_DATE', 'GEO', 'Index categories', 'VALUE']]

# %%
df.head()
# Out:
#    REF_DATE     GEO              Index categories  VALUE
# 0      1971  Canada   Education price index (EPI)  29.82
# 1      1971  Canada   Education price index (EPI)  22.82
# 2      1971  Canada  Salaries and wages sub-index  30.51
# 3      1971  Canada  Salaries and wages sub-index  23.36
# 4      1971  Canada  Teachers' salaries sub-index  30.91

# %%
# Adding index column
df.insert(0, 'Index', range(1, len(df) + 1))

# %%
df.head()
# Out:
#    Index  REF_DATE     GEO              Index categories  VALUE
# 0      1      1971  Canada   Education price index (EPI)  29.82
# 1      2      1971  Canada   Education price index (EPI)  22.82
# 2      3      1971  Canada  Salaries and wages sub-index  30.51
# 3      4      1971  Canada  Salaries and wages sub-index  23.36
# 4      5      1971  Canada  Teachers' salaries sub-index  30.91

# %%
#pivoting the Graduation rate column
df_pivot = df.pivot(index=['REF_DATE', 'GEO', 'Index'], columns="Index categories", values='VALUE').reset_index()

# %%
df_pivot
# Out:
# Index categories  REF_DATE           GEO  Index  Education price index (EPI)  \
# 0                     1971       Alberta    145                        30.13
# 1                     1971       Alberta    146                        23.92
# 2                     1971       Alberta    147                          NaN
# 3                     1971       Alberta    148                          NaN
# 4                     1971       Alberta    149                          NaN
# ...                    ...           ...    ...                          ...
# 5803                  2003  Saskatchewan   5772                          NaN
# 5804                  2003  Saskatchewan   5773                          NaN
# 5805                  2003  Saskatchewan   5774                          NaN
# 5806                  2003  Saskatchewan   5775                          NaN
# 5807                  2003  Saskatchewan   5776                          NaN
#
# Index categories  Fees and contractual services sub-index  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# ...                                                   ...
# 5803                                                  NaN
# 5804                                                  NaN
# 5805                                                  NaN
# 5806                                               208.37
# 5807                                               143.14
#
# Index categories  Instructional supplies sub-index  Non-salary sub-index  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
# ...                                            ...                   ...
# 5803                                        168.51                   NaN
# 5804                                           NaN                   NaN
# 5805                                           NaN                   NaN
# 5806                                           NaN                   NaN
# 5807                                           NaN                   NaN
#
# Index categories  Non-teaching salaries sub-index  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# ...                                           ...
# 5803                                          NaN
# 5804                                          NaN
# 5805                                          NaN
# 5806                                          NaN
# 5807                                          NaN
#
# Index categories  Salaries and wages sub-index  \
# 0                                          NaN
# 1                                          NaN
# 2                                        30.76
# 3                                        24.53
# 4                                          NaN
# ...                                        ...
# 5803                                       NaN
# 5804                                       NaN
# 5805                                       NaN
# 5806                                       NaN
# 5807                                       NaN
#
# Index categories  School facilities, supplies and services sub-index  \
# 0                                                               NaN
# 1                                                               NaN
# 2                                                               NaN
# 3                                                               NaN
# 4                                                               NaN
# ...                                                             ...
# 5803                                                            NaN
# 5804                                                         151.88
# 5805                                                         136.51
# 5806                                                            NaN
# 5807                                                            NaN
#
# Index categories  Teachers' salaries sub-index
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                        31.33
# ...                                        ...
# 5803                                       NaN
# 5804                                       NaN
# 5805                                       NaN
# 5806                                       NaN
# 5807                                       NaN
#
# [5808 rows x 11 columns]

# %%
df_pivot.reset_index(drop=True, inplace=True)
df_pivot.columns
# Out:
# Index(['REF_DATE', 'GEO', 'Index', 'Education price index (EPI)',
#        'Fees and contractual services sub-index',
#        'Instructional supplies sub-index', 'Non-salary sub-index',
#        'Non-teaching salaries sub-index', 'Salaries and wages sub-index',
#        'School facilities, supplies and services sub-index',
#        'Teachers' salaries sub-index'],
#       dtype='object', name='Index categories')

# %%
grouped_df = df_pivot.groupby(['REF_DATE', 'GEO'], as_index=False).agg({
    "Index": "first",
    "Education price index (EPI)": "first",
    "Fees and contractual services sub-index": "first",
    "Instructional supplies sub-index": "first",
    "Non-salary sub-index": "first",
    "Non-teaching salaries sub-index": "first",
    "Salaries and wages sub-index": "first",
    "School facilities, supplies and services sub-index": "first",
    "Teachers' salaries sub-index": "first"  # No issue inside double quotes
})

# %%
grouped_df
# Out:
# Index categories  REF_DATE                   GEO  Index  \
# 0                     1971               Alberta    145
# 1                     1971      British Columbia    161
# 2                     1971                Canada      1
# 3                     1971              Manitoba    113
# 4                     1971         New Brunswick     65
# ..                     ...                   ...    ...
# 358                   2003           Nova Scotia   5681
# 359                   2003               Ontario   5729
# 360                   2003  Prince Edward Island   5665
# 361                   2003                Quebec   5713
# 362                   2003          Saskatchewan   5761
#
# Index categories  Education price index (EPI)  \
# 0                                       30.13
# 1                                       30.19
# 2                                       29.82
# 3                                       29.49
# 4                                       27.93
# ..                                        ...
# 358                                    149.55
# 359                                    162.95
# 360                                    157.39
# 361                                    165.60
# 362                                    158.08
#
# Index categories  Fees and contractual services sub-index  \
# 0                                                   29.86
# 1                                                   25.15
# 2                                                   28.81
# 3                                                   31.80
# 4                                                   31.71
# ..                                                    ...
# 358                                                213.64
# 359                                                212.21
# 360                                                209.86
# 361                                                211.06
# 362                                                208.37
#
# Index categories  Instructional supplies sub-index  Non-salary sub-index  \
# 0                                            28.19                 27.24
# 1                                            28.19                 25.06
# 2                                            28.19                 26.93
# 3                                            28.19                 27.75
# 4                                            28.19                 27.28
# ..                                             ...                   ...
# 358                                         206.00                176.70
# 359                                         206.00                198.38
# 360                                         206.00                171.32
# 361                                         206.00                199.46
# 362                                         206.00                191.40
#
# Index categories  Non-teaching salaries sub-index  \
# 0                                           27.59
# 1                                           27.79
# 2                                           27.65
# 3                                           27.85
# 4                                           27.76
# ..                                            ...
# 358                                        154.86
# 359                                        148.67
# 360                                        164.34
# 361                                        153.07
# 362                                        151.53
#
# Index categories  Salaries and wages sub-index  \
# 0                                        30.76
# 1                                        31.13
# 2                                        30.51
# 3                                        29.88
# 4                                        28.10
# ..                                         ...
# 358                                     146.35
# 359                                     155.17
# 360                                     155.95
# 361                                     157.36
# 362                                     149.70
#
# Index categories  School facilities, supplies and services sub-index  \
# 0                                                             23.58
# 1                                                             22.67
# 2                                                             23.51
# 3                                                             23.81
# 4                                                             24.67
# ..                                                              ...
# 358                                                          130.50
# 359                                                          172.16
# 360                                                          139.54
# 361                                                          156.89
# 362                                                          151.88
#
# Index categories  Teachers' salaries sub-index
# 0                                        31.33
# 1                                        31.82
# 2                                        30.91
# 3                                        30.22
# 4                                        28.22
# ..                                         ...
# 358                                     145.24
# 359                                     155.94
# 360                                     154.49
# 361                                     157.82
# 362                                     149.35
#
# [363 rows x 11 columns]

# %%
#Dropping the Index column
grouped_df.drop(columns=['Index'], inplace=True)

# %%
grouped_df
# Out:
# Index categories  REF_DATE                   GEO  Education price index (EPI)  \
# 0                     1971               Alberta                        30.13
# 1                     1971      British Columbia                        30.19
# 2                     1971                Canada                        29.82
# 3                     1971              Manitoba                        29.49
# 4                     1971         New Brunswick                        27.93
# ..                     ...                   ...                          ...
# 358                   2003           Nova Scotia                       149.55
# 359                   2003               Ontario                       162.95
# 360                   2003  Prince Edward Island                       157.39
# 361                   2003                Quebec                       165.60
# 362                   2003          Saskatchewan                       158.08
#
# Index categories  Fees and contractual services sub-index  \
# 0                                                   29.86
# 1                                                   25.15
# 2                                                   28.81
# 3                                                   31.80
# 4                                                   31.71
# ..                                                    ...
# 358                                                213.64
# 359                                                212.21
# 360                                                209.86
# 361                                                211.06
# 362                                                208.37
#
# Index categories  Instructional supplies sub-index  Non-salary sub-index  \
# 0                                            28.19                 27.24
# 1                                            28.19                 25.06
# 2                                            28.19                 26.93
# 3                                            28.19                 27.75
# 4                                            28.19                 27.28
# ..                                             ...                   ...
# 358                                         206.00                176.70
# 359                                         206.00                198.38
# 360                                         206.00                171.32
# 361                                         206.00                199.46
# 362                                         206.00                191.40
#
# Index categories  Non-teaching salaries sub-index  \
# 0                                           27.59
# 1                                           27.79
# 2                                           27.65
# 3                                           27.85
# 4                                           27.76
# ..                                            ...
# 358                                        154.86
# 359                                        148.67
# 360                                        164.34
# 361                                        153.07
# 362                                        151.53
#
# Index categories  Salaries and wages sub-index  \
# 0                                        30.76
# 1                                        31.13
# 2                                        30.51
# 3                                        29.88
# 4                                        28.10
# ..                                         ...
# 358                                     146.35
# 359                                     155.17
# 360                                     155.95
# 361                                     157.36
# 362                                     149.70
#
# Index categories  School facilities, supplies and services sub-index  \
# 0                                                             23.58
# 1                                                             22.67
# 2                                                             23.51
# 3                                                             23.81
# 4                                                             24.67
# ..                                                              ...
# 358                                                          130.50
# 359                                                          172.16
# 360                                                          139.54
# 361                                                          156.89
# 362                                                          151.88
#
# Index categories  Teachers' salaries sub-index
# 0                                        31.33
# 1                                        31.82
# 2                                        30.91
# 3                                        30.22
# 4                                        28.22
# ..                                         ...
# 358                                     145.24
# 359                                     155.94
# 360                                     154.49
# 361                                     157.82
# 362                                     149.35
#
# [363 rows x 10 columns]

# %%
# Remove column index name if it exists
grouped_df.columns.name = None

# %%
grouped_df
# Out:
#      REF_DATE                   GEO  Education price index (EPI)  \
# 0        1971               Alberta                        30.13
# 1        1971      British Columbia                        30.19
# 2        1971                Canada                        29.82
# 3        1971              Manitoba                        29.49
# 4        1971         New Brunswick                        27.93
# ..        ...                   ...                          ...
# 358      2003           Nova Scotia                       149.55
# 359      2003               Ontario                       162.95
# 360      2003  Prince Edward Island                       157.39
# 361      2003                Quebec                       165.60
# 362      2003          Saskatchewan                       158.08
#
#      Fees and contractual services sub-index  \
# 0                                      29.86
# 1                                      25.15
# 2                                      28.81
# 3                                      31.80
# 4                                      31.71
# ..                                       ...
# 358                                   213.64
# 359                                   212.21
# 360                                   209.86
# 361                                   211.06
# 362                                   208.37
#
#      Instructional supplies sub-index  Non-salary sub-index  \
# 0                               28.19                 27.24
# 1                               28.19                 25.06
# 2                               28.19                 26.93
# 3                               28.19                 27.75
# 4                               28.19                 27.28
# ..                                ...                   ...
# 358                            206.00                176.70
# 359                            206.00                198.38
# 360                            206.00                171.32
# 361                            206.00                199.46
# 362                            206.00                191.40
#
#      Non-teaching salaries sub-index  Salaries and wages sub-index  \
# 0                              27.59                         30.76
# 1                              27.79                         31.13
# 2                              27.65                         30.51
# 3                              27.85                         29.88
# 4                              27.76                         28.10
# ..                               ...                           ...
# 358                           154.86                        146.35
# 359                           148.67                        155.17
# 360                           164.34                        155.95
# 361                           153.07                        157.36
# 362                           151.53                        149.70
#
#      School facilities, supplies and services sub-index  \
# 0                                                23.58
# 1                                                22.67
# 2                                                23.51
# 3                                                23.81
# 4                                                24.67
# ..                                                 ...
# 358                                             130.50
# 359                                             172.16
# 360                                             139.54
# 361                                             156.89
# 362                                             151.88
#
#      Teachers' salaries sub-index
# 0                           31.33
# 1                           31.82
# 2                           30.91
# 3                           30.22
# 4                           28.22
# ..                            ...
# 358                        145.24
# 359                        155.94
# 360                        154.49
# 361                        157.82
# 362                        149.35
#
# [363 rows x 10 columns]

# %%
grouped_df.to_csv("Prepared_EPI.csv", index=False)
