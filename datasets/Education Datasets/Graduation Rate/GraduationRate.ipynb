# %%
import pandas as pd
import os

# %%
# Define the folder path where the CSV files are located
folder_path = "."

# %%
# Get a list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith(".csv")]

# %%
# Initialize an empty list to store DataFrames
dfs = []

# Read each CSV file and append it to the list
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    df['Source_File'] = file  # Optional: Track the file each row came from
    dfs.append(df)

# Concatenate all DataFrames
merged_df = pd.concat(dfs, ignore_index=True)

# %%
merged_df
# Out:
#       REF_DATE           GEO        DGUID Graduation rate         Gender  \
# 0    2016/2017       Alberta  2021A000248         On-time   Total gender
# 1    2017/2018       Alberta  2021A000248         On-time   Total gender
# 2    2018/2019       Alberta  2021A000248         On-time   Total gender
# 3    2019/2020       Alberta  2021A000248         On-time   Total gender
# 4    2020/2021       Alberta  2021A000248         On-time   Total gender
# ..         ...           ...          ...             ...            ...
# 463  2017/2018  Saskatchewan  2021A000247   Extended-time  Female gender
# 464  2018/2019  Saskatchewan  2021A000247   Extended-time  Female gender
# 465  2019/2020  Saskatchewan  2021A000247   Extended-time  Female gender
# 466  2020/2021  Saskatchewan  2021A000247   Extended-time  Female gender
# 467  2021/2022  Saskatchewan  2021A000247   Extended-time  Female gender
#
#          UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE  VALUE  \
# 0    Percent     239         units          0  v1391416755     10.1.1   78.0
# 1    Percent     239         units          0  v1391416755     10.1.1   80.0
# 2    Percent     239         units          0  v1391416755     10.1.1   80.0
# 3    Percent     239         units          0  v1391416755     10.1.1   84.0
# 4    Percent     239         units          0  v1391416755     10.1.1   84.0
# ..       ...     ...           ...        ...          ...        ...    ...
# 463  Percent     239         units          0  v1391416754      9.2.3   86.0
# 464  Percent     239         units          0  v1391416754      9.2.3   88.0
# 465  Percent     239         units          0  v1391416754      9.2.3   90.0
# 466  Percent     239         units          0  v1391416754      9.2.3   92.0
# 467  Percent     239         units          0  v1391416754      9.2.3   92.0
#
#     STATUS  SYMBOL  TERMINATED  DECIMALS       Source_File
# 0      NaN     NaN         NaN         0       Alberta.csv
# 1      NaN     NaN         NaN         0       Alberta.csv
# 2      NaN     NaN         NaN         0       Alberta.csv
# 3      NaN     NaN         NaN         0       Alberta.csv
# 4      NaN     NaN         NaN         0       Alberta.csv
# ..     ...     ...         ...       ...               ...
# 463    NaN     NaN         NaN         0  Saskatchewan.csv
# 464    NaN     NaN         NaN         0  Saskatchewan.csv
# 465    NaN     NaN         NaN         0  Saskatchewan.csv
# 466    NaN     NaN         NaN         0  Saskatchewan.csv
# 467    NaN     NaN         NaN         0  Saskatchewan.csv
#
# [468 rows x 17 columns]

# %%
# Keep only the left year
merged_df['REF_DATE'] = merged_df['REF_DATE'].str[:4]

# %%
merged_df
# Out:
#     REF_DATE           GEO        DGUID Graduation rate         Gender  \
# 0       2016       Alberta  2021A000248         On-time   Total gender
# 1       2017       Alberta  2021A000248         On-time   Total gender
# 2       2018       Alberta  2021A000248         On-time   Total gender
# 3       2019       Alberta  2021A000248         On-time   Total gender
# 4       2020       Alberta  2021A000248         On-time   Total gender
# ..       ...           ...          ...             ...            ...
# 463     2017  Saskatchewan  2021A000247   Extended-time  Female gender
# 464     2018  Saskatchewan  2021A000247   Extended-time  Female gender
# 465     2019  Saskatchewan  2021A000247   Extended-time  Female gender
# 466     2020  Saskatchewan  2021A000247   Extended-time  Female gender
# 467     2021  Saskatchewan  2021A000247   Extended-time  Female gender
#
#          UOM  UOM_ID SCALAR_FACTOR  SCALAR_ID       VECTOR COORDINATE  VALUE  \
# 0    Percent     239         units          0  v1391416755     10.1.1   78.0
# 1    Percent     239         units          0  v1391416755     10.1.1   80.0
# 2    Percent     239         units          0  v1391416755     10.1.1   80.0
# 3    Percent     239         units          0  v1391416755     10.1.1   84.0
# 4    Percent     239         units          0  v1391416755     10.1.1   84.0
# ..       ...     ...           ...        ...          ...        ...    ...
# 463  Percent     239         units          0  v1391416754      9.2.3   86.0
# 464  Percent     239         units          0  v1391416754      9.2.3   88.0
# 465  Percent     239         units          0  v1391416754      9.2.3   90.0
# 466  Percent     239         units          0  v1391416754      9.2.3   92.0
# 467  Percent     239         units          0  v1391416754      9.2.3   92.0
#
#     STATUS  SYMBOL  TERMINATED  DECIMALS       Source_File
# 0      NaN     NaN         NaN         0       Alberta.csv
# 1      NaN     NaN         NaN         0       Alberta.csv
# 2      NaN     NaN         NaN         0       Alberta.csv
# 3      NaN     NaN         NaN         0       Alberta.csv
# 4      NaN     NaN         NaN         0       Alberta.csv
# ..     ...     ...         ...       ...               ...
# 463    NaN     NaN         NaN         0  Saskatchewan.csv
# 464    NaN     NaN         NaN         0  Saskatchewan.csv
# 465    NaN     NaN         NaN         0  Saskatchewan.csv
# 466    NaN     NaN         NaN         0  Saskatchewan.csv
# 467    NaN     NaN         NaN         0  Saskatchewan.csv
#
# [468 rows x 17 columns]

# %%
# Keep only the required columns
merged_df = merged_df[['REF_DATE', 'GEO', 'Graduation rate', 'VALUE']]

# %%
merged_df
# Out:
#     REF_DATE           GEO Graduation rate  VALUE
# 0       2016       Alberta         On-time   78.0
# 1       2017       Alberta         On-time   80.0
# 2       2018       Alberta         On-time   80.0
# 3       2019       Alberta         On-time   84.0
# 4       2020       Alberta         On-time   84.0
# ..       ...           ...             ...    ...
# 463     2017  Saskatchewan   Extended-time   86.0
# 464     2018  Saskatchewan   Extended-time   88.0
# 465     2019  Saskatchewan   Extended-time   90.0
# 466     2020  Saskatchewan   Extended-time   92.0
# 467     2021  Saskatchewan   Extended-time   92.0
#
# [468 rows x 4 columns]

# %%
# Adding index column
merged_df.insert(0, 'Index', range(1, len(merged_df) + 1))

# %%
merged_df
# Out:
#      Index REF_DATE           GEO Graduation rate  VALUE
# 0        1     2016       Alberta         On-time   78.0
# 1        2     2017       Alberta         On-time   80.0
# 2        3     2018       Alberta         On-time   80.0
# 3        4     2019       Alberta         On-time   84.0
# 4        5     2020       Alberta         On-time   84.0
# ..     ...      ...           ...             ...    ...
# 463    464     2017  Saskatchewan   Extended-time   86.0
# 464    465     2018  Saskatchewan   Extended-time   88.0
# 465    466     2019  Saskatchewan   Extended-time   90.0
# 466    467     2020  Saskatchewan   Extended-time   92.0
# 467    468     2021  Saskatchewan   Extended-time   92.0
#
# [468 rows x 5 columns]

# %%
#pivoting the Graduation rate column
df_pivot = merged_df.pivot(index=['REF_DATE', 'GEO', 'Index'], columns="Graduation rate", values='VALUE').reset_index()

# %%
df_pivot
# Out:
# Graduation rate REF_DATE           GEO  Index  Extended-time  On-time
# 0                   2016       Alberta      1            NaN     78.0
# 1                   2016       Alberta      7            NaN     76.0
# 2                   2016       Alberta     13            NaN     81.0
# 3                   2016       Alberta     19           84.0      NaN
# 4                   2016       Alberta     25           82.0      NaN
# ..                   ...           ...    ...            ...      ...
# 463                 2021  Saskatchewan    444            NaN     82.0
# 464                 2021  Saskatchewan    450            NaN     84.0
# 465                 2021  Saskatchewan    456           91.0      NaN
# 466                 2021  Saskatchewan    462           89.0      NaN
# 467                 2021  Saskatchewan    468           92.0      NaN
#
# [468 rows x 5 columns]

# %%
df_pivot.reset_index(drop=True, inplace=True)
df_pivot.columns
# Out:
# Index(['REF_DATE', 'GEO', 'Index', 'Extended-time', 'On-time'], dtype='object', name='Graduation rate')

# %%
## Group the data by REF_DATE and GEO without setting them as index
grouped_df = df_pivot.groupby(['REF_DATE', 'GEO'], as_index=False).agg({
    'Index': 'first',  
    'Extended-time': 'first',    
    'On-time': 'first'  
})

# %%
grouped_df
# Out:
# Graduation rate REF_DATE               GEO  Index  Extended-time  On-time
# 0                   2016           Alberta      1           84.0     78.0
# 1                   2016  British Columbia     37           88.0     81.0
# 2                   2016            Canada     73           87.0     80.0
# 3                   2016          Manitoba    109           87.0     82.0
# 4                   2016     New Brunswick    145           85.0     85.0
# ..                   ...               ...    ...            ...      ...
# 67                  2021       Nova Scotia    258           96.0     91.0
# 68                  2021           Nunavut    294            NaN      NaN
# 69                  2021           Ontario    330           94.0     87.0
# 70                  2021            Quebec    402           86.0     76.0
# 71                  2021      Saskatchewan    438           91.0     83.0
#
# [72 rows x 5 columns]

# %%
#Dropping the Index column
grouped_df.drop(columns=['Index'], inplace=True)

# %%
# Remove column index name if it exists
grouped_df.columns.name = None

# %%
grouped_df
# Out:
#    REF_DATE               GEO  Extended-time  On-time
# 0      2016           Alberta           84.0     78.0
# 1      2016  British Columbia           88.0     81.0
# 2      2016            Canada           87.0     80.0
# 3      2016          Manitoba           87.0     82.0
# 4      2016     New Brunswick           85.0     85.0
# ..      ...               ...            ...      ...
# 67     2021       Nova Scotia           96.0     91.0
# 68     2021           Nunavut            NaN      NaN
# 69     2021           Ontario           94.0     87.0
# 70     2021            Quebec           86.0     76.0
# 71     2021      Saskatchewan           91.0     83.0
#
# [72 rows x 4 columns]

# %%
# Define the list of GEO values to keep
geo_list = [
    "Canada", "Quebec", "Ontario", "British Columbia", "Alberta", 
    "Manitoba", "New Brunswick", "Newfoundland and Labrador", 
    "Nova Scotia", "Saskatchewan", "Prince Edward Island"
]

# Filter the DataFrame to keep only these GEO values
grouped_df = grouped_df[grouped_df['GEO'].isin(geo_list)].reset_index(drop=True)

# %%
grouped_df
# Out:
#    REF_DATE                        GEO  Extended-time  On-time
# 0      2016                    Alberta           84.0     78.0
# 1      2016           British Columbia           88.0     81.0
# 2      2016                     Canada           87.0     80.0
# 3      2016                   Manitoba           87.0     82.0
# 4      2016              New Brunswick           85.0     85.0
# 5      2016  Newfoundland and Labrador           90.0     88.0
# 6      2016                Nova Scotia            NaN      NaN
# 7      2016                    Ontario           92.0     82.0
# 8      2016                     Quebec           82.0     74.0
# 9      2016               Saskatchewan           85.0     78.0
# 10     2017                    Alberta           86.0     80.0
# 11     2017           British Columbia           88.0     81.0
# 12     2017                     Canada           88.0     81.0
# 13     2017                   Manitoba           87.0     83.0
# 14     2017              New Brunswick           90.0     86.0
# 15     2017  Newfoundland and Labrador           92.0     88.0
# 16     2017                Nova Scotia           90.0     87.0
# 17     2017                    Ontario           91.0     82.0
# 18     2017                     Quebec           84.0     75.0
# 19     2017               Saskatchewan           84.0     79.0
# 20     2018                    Alberta           86.0     80.0
# 21     2018           British Columbia           89.0     81.0
# 22     2018                     Canada           89.0     81.0
# 23     2018                   Manitoba           88.0     82.0
# 24     2018              New Brunswick           89.0     85.0
# 25     2018  Newfoundland and Labrador           92.0     89.0
# 26     2018                Nova Scotia           90.0     86.0
# 27     2018                    Ontario           92.0     83.0
# 28     2018                     Quebec           84.0     75.0
# 29     2018               Saskatchewan           86.0     80.0
# 30     2019                    Alberta           87.0     84.0
# 31     2019           British Columbia           89.0     84.0
# 32     2019                     Canada           89.0     84.0
# 33     2019                   Manitoba           87.0     82.0
# 34     2019              New Brunswick           89.0     87.0
# 35     2019  Newfoundland and Labrador           92.0     94.0
# 36     2019                Nova Scotia           91.0     92.0
# 37     2019                    Ontario           92.0     86.0
# 38     2019                     Quebec           83.0     79.0
# 39     2019               Saskatchewan           88.0     85.0
# 40     2020                    Alberta           88.0     84.0
# 41     2020           British Columbia           89.0     83.0
# 42     2020                     Canada           89.0     84.0
# 43     2020                   Manitoba           89.0     85.0
# 44     2020              New Brunswick           87.0     87.0
# 45     2020  Newfoundland and Labrador           94.0     89.0
# 46     2020                Nova Scotia           92.0     87.0
# 47     2020                    Ontario           93.0     85.0
# 48     2020                     Quebec           83.0     80.0
# 49     2020               Saskatchewan           89.0     83.0
# 50     2021                    Alberta           90.0     82.0
# 51     2021           British Columbia           87.0     84.0
# 52     2021                     Canada           91.0     84.0
# 53     2021                   Manitoba           88.0     84.0
# 54     2021              New Brunswick           90.0     85.0
# 55     2021  Newfoundland and Labrador           97.0     89.0
# 56     2021                Nova Scotia           96.0     91.0
# 57     2021                    Ontario           94.0     87.0
# 58     2021                     Quebec           86.0     76.0
# 59     2021               Saskatchewan           91.0     83.0

# %%
# Perform linear interpolation for numerical columns
grouped_df[['Extended-time', 'On-time']] = grouped_df[['Extended-time', 'On-time']].interpolate(method='linear')

# %%
grouped_df
# Out:
#    REF_DATE                        GEO  Extended-time  On-time
# 0      2016                    Alberta           84.0     78.0
# 1      2016           British Columbia           88.0     81.0
# 2      2016                     Canada           87.0     80.0
# 3      2016                   Manitoba           87.0     82.0
# 4      2016              New Brunswick           85.0     85.0
# 5      2016  Newfoundland and Labrador           90.0     88.0
# 6      2016                Nova Scotia           91.0     85.0
# 7      2016                    Ontario           92.0     82.0
# 8      2016                     Quebec           82.0     74.0
# 9      2016               Saskatchewan           85.0     78.0
# 10     2017                    Alberta           86.0     80.0
# 11     2017           British Columbia           88.0     81.0
# 12     2017                     Canada           88.0     81.0
# 13     2017                   Manitoba           87.0     83.0
# 14     2017              New Brunswick           90.0     86.0
# 15     2017  Newfoundland and Labrador           92.0     88.0
# 16     2017                Nova Scotia           90.0     87.0
# 17     2017                    Ontario           91.0     82.0
# 18     2017                     Quebec           84.0     75.0
# 19     2017               Saskatchewan           84.0     79.0
# 20     2018                    Alberta           86.0     80.0
# 21     2018           British Columbia           89.0     81.0
# 22     2018                     Canada           89.0     81.0
# 23     2018                   Manitoba           88.0     82.0
# 24     2018              New Brunswick           89.0     85.0
# 25     2018  Newfoundland and Labrador           92.0     89.0
# 26     2018                Nova Scotia           90.0     86.0
# 27     2018                    Ontario           92.0     83.0
# 28     2018                     Quebec           84.0     75.0
# 29     2018               Saskatchewan           86.0     80.0
# 30     2019                    Alberta           87.0     84.0
# 31     2019           British Columbia           89.0     84.0
# 32     2019                     Canada           89.0     84.0
# 33     2019                   Manitoba           87.0     82.0
# 34     2019              New Brunswick           89.0     87.0
# 35     2019  Newfoundland and Labrador           92.0     94.0
# 36     2019                Nova Scotia           91.0     92.0
# 37     2019                    Ontario           92.0     86.0
# 38     2019                     Quebec           83.0     79.0
# 39     2019               Saskatchewan           88.0     85.0
# 40     2020                    Alberta           88.0     84.0
# 41     2020           British Columbia           89.0     83.0
# 42     2020                     Canada           89.0     84.0
# 43     2020                   Manitoba           89.0     85.0
# 44     2020              New Brunswick           87.0     87.0
# 45     2020  Newfoundland and Labrador           94.0     89.0
# 46     2020                Nova Scotia           92.0     87.0
# 47     2020                    Ontario           93.0     85.0
# 48     2020                     Quebec           83.0     80.0
# 49     2020               Saskatchewan           89.0     83.0
# 50     2021                    Alberta           90.0     82.0
# 51     2021           British Columbia           87.0     84.0
# 52     2021                     Canada           91.0     84.0
# 53     2021                   Manitoba           88.0     84.0
# 54     2021              New Brunswick           90.0     85.0
# 55     2021  Newfoundland and Labrador           97.0     89.0
# 56     2021                Nova Scotia           96.0     91.0
# 57     2021                    Ontario           94.0     87.0
# 58     2021                     Quebec           86.0     76.0
# 59     2021               Saskatchewan           91.0     83.0

# %%
grouped_df.to_csv("Prepared_GraduationRate.csv", index=False)
